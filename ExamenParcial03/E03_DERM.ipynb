# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def alpha_beta(node, alpha, beta, maximizing_player, pruned, depth):
    if isinstance(tree[node], int):
        return tree[node]  

    children = tree[node] 
    if maximizing_player:
        max_eval = float('-inf')
        for child in children:
            eval = alpha_beta(child, alpha, beta, False, pruned, depth - 1)
            max_eval = max(max_eval, eval)
            alpha = max(alpha, eval)
            if beta <= alpha:
                pruned.extend(children[children.index(child)+1:])  
                break
        return max_eval
    else:
        min_eval = float('inf')
        for child in children:
            eval = alpha_beta(child, alpha, beta, True, pruned, depth - 1)
            min_eval = min(min_eval, eval)
            beta = min(beta, eval)
            if beta <= alpha:
                pruned.extend(children[children.index(child)+1:]) 
                break
        return min_eval
    
tree = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F', 'G'],
    'D': ['H', 'I'],
    'E': ['J', 'K'],
    'F': ['L', 'M'],
    'G': ['N', 'O'],
    'H': 3, 'I': 1, 'J': 4, 'K': 1, 'L': 5, 'M': 9, 'N': 2, 'O': 6
}

pruned = []
# Start the alpha-beta pruning
result = alpha_beta('A', float('-inf'), float('inf'), True, pruned, 3)

print("Value:", result)
print("Pruned nodes values:", pruned)
# Out:
# Value: 6
# Pruned nodes values: ['K']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def alpha_beta(node, alpha, beta, maximizing_player, pruned, depth):
    if isinstance(tree[node], int):
        return tree[node]

    children = tree[node] 
    if maximizing_player:
        max_eval = float('-inf')
        for child in children:
            eval = alpha_beta(child, alpha, beta, False, pruned, depth - 1)
            max_eval = max(max_eval, eval)
            alpha = max(alpha, eval)
            if beta <= alpha:
                pruned.extend(children[children.index(child)+1:]) 
                break
        return max_eval
    else:
        min_eval = float('inf')
        for child in children:
            eval = alpha_beta(child, alpha, beta, True, pruned, depth - 1)
            min_eval = min(min_eval, eval)
            beta = min(beta, eval)
            if beta <= alpha:
                pruned.extend(children[children.index(child)+1:])  
                break
        return min_eval

tree = {
    'A': ['B', 'C', 'D'],
    'B': ['E', 'F', 'G'],
    'C': ['H', 'I', 'J'],
    'D': ['K', 'L', 'M'],
    'E': 4, 'F': 8, 'G': 5, 'H': 9, 'I': 3, 'J': 7, 'K': 2, 'L': 4, 'M': 6
}

pruned = []
result = alpha_beta('A', float('-inf'), float('inf'), True, pruned, 3)

print("Value:", result)
print("Pruned nodes values:", pruned)
# Out:
# Value: 4
# Pruned nodes values: ['J', 'L', 'M']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def alpha_beta(node, alpha, beta, maximizing_player, pruned, depth):
    # with this we chec the current node, basically we retrieve the value 
    if isinstance(tree[node], int):
        return tree[node]  # Return the leaf node 

    children = tree[node] # Get the children of the current node
    if maximizing_player:
        max_eval = float('-inf')
        for child in children:
            eval = alpha_beta(child, alpha, beta, False, pruned, depth - 1)
            max_eval = max(max_eval, eval)
            alpha = max(alpha, eval)
            if beta <= alpha:
                pruned.extend(children[children.index(child)+1:])  # Add remaining children to our prunned list
                break
        return max_eval
    else:
        min_eval = float('inf')
        for child in children:
            eval = alpha_beta(child, alpha, beta, True, pruned, depth - 1)
            min_eval = min(min_eval, eval)
            beta = min(beta, eval)
            if beta <= alpha:
                pruned.extend(children[children.index(child)+1:])  # Add remaining children to our prunned list
                break
        return min_eval

tree = {
    'A': ['B', 'C', 'D'],
    'B': ['E', 'F', 'G'],
    'C': ['H', 'I', 'J'],
    'D': ['K', 'L', 'M'],
    'E': ['N', 'O', 'P'],
    'F': ['Q', 'R', 'S'],
    'G': ['T', 'U', 'V'],
    'H': ['W', 'X', 'Y'],
    'I': ['Z', 'a', 'b'],
    'J': ['c', 'd', 'e'],
    'K': ['f', 'g', 'h'],
    'L': ['i', 'j', 'k'],
    'M': ['l', 'm', 'n'],
    'N':5, 'O':3, 'P':5, 'Q':8, 'R':9, 'S':7,'T':9, 'U':3, 'V':2,'W':3, 'X':8, 'Y':4,'Z':6, 'a':2, 'b':6,'c':4, 'd':3, 'e':3,'f':8, 'g':3, 'h':2,'i':7, 'j':9, 'k':5,'l':0, 'm':2, 'n':8
}

pruned = []
result = alpha_beta('A', float('-inf'), float('inf'), True, pruned, 3)

print("Value:", result)
print("Pruned nodes values:", pruned)
# Out:
# Value: 8
# Pruned nodes values: ['R', 'S', 'U', 'V', 'k']
